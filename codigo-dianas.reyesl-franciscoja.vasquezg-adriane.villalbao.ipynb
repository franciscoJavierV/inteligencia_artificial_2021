# %%
# importar la librría matplotlib para graficar

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
# se llama el archivo para cargar los datos

# %%
df = pd.read_csv("googleplaystore_user_reviews.csv")

# %%
df.dropna( inplace=True )

# %%
# %matplotlib inline

# %%
x = pd.DataFrame(df)

# %%
# en la siguienye línea se modifican los estilos de las gráficas

# %%
plt.style.use('dark_background')

# %%
# Gráfica de Sentimiento vs Subjetividad del Sentimiento

# %%
x.groupby('Sentiment')['Sentiment_Subjectivity'].sum().plot(kind='bar', title='Sentimiento vs Subjetividad')

# %%
x.groupby('Sentiment_Polarity')['Sentiment_Subjectivity'].sum().plot()

# %%
# en la siguiente línea se grafica la polaridad y el sentimiento

# %%
ax2 = df.plot.scatter(x='Sentiment',
                      y='Sentiment_Polarity')

# %%
x.groupby('Sentiment')['Sentiment_Subjectivity'].sum().plot()

# %%
df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
import matplotlib.gridspec as gridspec

# %%
import numpy as np

# %%
sentimentindex=np.array(df.keys())

# %%
pd.DataFrame.hist(df, layout=(7,2), figsize=(15,15), bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f31f5b80dd0>,
# ...
#       dtype=object)
